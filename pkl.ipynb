# %%
import joblib

districts = joblib.load('available_districts.pkl')

# districts = [
#     'Panchagarh' if d == 'Panchagar' else d 
#     for d in districts
# ]

# Add Chapai Nawabganj if missing
if 'Chapai Nawabganj' not in districts and 'Chapainawabganj' not in districts:
    districts.append('Chapai Nawabganj')
    districts = sorted(districts)

print("After:", districts)

joblib.dump(districts, 'available_districts.pkl')
print("Done.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 import joblib
# ----> 3 districts = joblib.load('available_districts.pkl')
#       5 # districts = [
#       6 #     'Panchagarh' if d == 'Panchagar' else d
#       7 #     for d in districts
#       8 # ]
#       9
#      10 # Add Chapai Nawabganj if missing
#      11 if 'Chapai Nawabganj' not in districts and 'Chapainawabganj' not in districts:
#
# File c:\Users\mdsal\anaconda3\envs\test\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# ...
